# %% [markdown]
# ## 1. Importing the Required Python Libraries

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import plotly.express as px

import bar_chart_race as bcr

# %%
df = pd.read_csv("E:\Data Analysis\Projects\StrataScratch Projects\Terrorism\datasets/globalterrorismdb_0718dist.tar.bz2", compression="bz2")
# Out:
# E:\APPS\Anaconda\Anaconda\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (5,7,32,34,62,63,64,77,80,91,93,95,97,115,116,122) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df.head()
# Out:
#    Unnamed: 0       eventid  iyear  imonth  iday approxdate  extended  \
# 0           0  197000000001   1970       7     2        NaN         0
# 1           1  197000000002   1970       0     0        NaN         0
# 2           2  197001000001   1970       1     0        NaN         0
# 3           3  197001000002   1970       1     0        NaN         0
# 4           4  197001000003   1970       1     0        NaN         0
#
#   resolution  country         country_txt  ...  addnotes scite1 scite2 scite3  \
# 0        NaN       58  Dominican Republic  ...       NaN    NaN    NaN    NaN
# 1        NaN      130              Mexico  ...       NaN    NaN    NaN    NaN
# 2        NaN      160         Philippines  ...       NaN    NaN    NaN    NaN
# 3        NaN       78              Greece  ...       NaN    NaN    NaN    NaN
# 4        NaN      101               Japan  ...       NaN    NaN    NaN    NaN
#
#    dbsource  INT_LOG  INT_IDEO  INT_MISC INT_ANY related
# ...

# %%
df.tail()
# Out:
#         Unnamed: 0       eventid  iyear  imonth  iday approxdate  extended  \
# 181686      181686  201712310022   2017      12    31        NaN         0
# 181687      181687  201712310029   2017      12    31        NaN         0
# 181688      181688  201712310030   2017      12    31        NaN         0
# 181689      181689  201712310031   2017      12    31        NaN         0
# 181690      181690  201712310032   2017      12    31        NaN         0
#
#        resolution  country  country_txt  ...  addnotes  \
# 181686        NaN      182      Somalia  ...       NaN
# 181687        NaN      200        Syria  ...       NaN
# 181688        NaN      160  Philippines  ...       NaN
# 181689        NaN       92        India  ...       NaN
# 181690        NaN      160  Philippines  ...       NaN
#
#                                                    scite1  \
# 181686  "Somalia: Al-Shabaab Militants Attack Army Che...
# 181687  "Putin's 'victory' in Syria has turned into a ...
# ...

# %%
select_columns = """success 
suicide 
attacktype1
attacktype1_txt 
targtype1_txt 
targsubtype1_txt 
target1 
natlty1_txt 
gname 
gsubname 
nperps 
weaptype1_txt 
weapsubtype1_txt 
nkill
nkillus """

# %%
df.columns.all
# Out:
# <bound method Index._add_logical_methods.<locals>._make_logical_function.<locals>.logical_func of Index(['Unnamed: 0', 'eventid', 'iyear', 'imonth', 'iday', 'approxdate',
#        'extended', 'resolution', 'country', 'country_txt',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=136)>

# %%
print(df.columns.tolist())
# Out:
# ['Unnamed: 0', 'eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended', 'resolution', 'country', 'country_txt', 'region', 'region_txt', 'provstate', 'city', 'latitude', 'longitude', 'specificity', 'vicinity', 'location', 'summary', 'crit1', 'crit2', 'crit3', 'doubtterr', 'alternative', 'alternative_txt', 'multiple', 'success', 'suicide', 'attacktype1', 'attacktype1_txt', 'attacktype2', 'attacktype2_txt', 'attacktype3', 'attacktype3_txt', 'targtype1', 'targtype1_txt', 'targsubtype1', 'targsubtype1_txt', 'corp1', 'target1', 'natlty1', 'natlty1_txt', 'targtype2', 'targtype2_txt', 'targsubtype2', 'targsubtype2_txt', 'corp2', 'target2', 'natlty2', 'natlty2_txt', 'targtype3', 'targtype3_txt', 'targsubtype3', 'targsubtype3_txt', 'corp3', 'target3', 'natlty3', 'natlty3_txt', 'gname', 'gsubname', 'gname2', 'gsubname2', 'gname3', 'gsubname3', 'motive', 'guncertain1', 'guncertain2', 'guncertain3', 'individual', 'nperps', 'nperpcap', 'claimed', 'claimmode', 'claimmode_txt', 'claim2', 'cla
# ...

# %%
['iyear', 'country_txt', 'region_txt', 'latitude', 'longitude', 'weaptype1']
# Out:
# ['iyear', 'country_txt', 'region_txt', 'latitude', 'longitude', 'weaptype1']

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
df.tail()
# Out:
#         Unnamed: 0       eventid  iyear  imonth  iday approxdate  extended  \
# 181686      181686  201712310022   2017      12    31        NaN         0
# 181687      181687  201712310029   2017      12    31        NaN         0
# 181688      181688  201712310030   2017      12    31        NaN         0
# 181689      181689  201712310031   2017      12    31        NaN         0
# 181690      181690  201712310032   2017      12    31        NaN         0
#
#        resolution  country  country_txt  region                  region_txt  \
# 181686        NaN      182      Somalia      11          Sub-Saharan Africa
# 181687        NaN      200        Syria      10  Middle East & North Africa
# 181688        NaN      160  Philippines       5              Southeast Asia
# 181689        NaN       92        India       6                  South Asia
# 181690        NaN      160  Philippines       5              Southeast Asia
#
# ...

# %% [markdown]
# ### How has the number of terrorist activities changed over the years?

# %%
df2 = df.groupby(['iyear'], as_index=True).count()[['eventid']]

# %%
df2.plot.bar(xlabel='Year', ylabel='Number of attacks', title='Number of attacks per year (1970-2017)', figsize=(15, 8))
# Out:
# <AxesSubplot:title={'center':'Number of attacks per year (1970-2017)'}, xlabel='Year', ylabel='Number of attacks'>

# %% [markdown]
# ### Number of Attacks per region, per year

# %%
df.region_txt.unique()
# Out:
# array(['Central America & Caribbean', 'North America', 'Southeast Asia',
#        'Western Europe', 'East Asia', 'South America', 'Eastern Europe',
#        'Sub-Saharan Africa', 'Middle East & North Africa',
#        'Australasia & Oceania', 'South Asia', 'Central Asia'],
#       dtype=object)

# %%
df3 = df[['region_txt', 'iyear', 'eventid', 'nkill']].groupby(['region_txt', 'iyear']).agg({'eventid':'count', 'nkill':'sum'})

# %%
df3.index.levels[0].unique()
# Out:
# Index(['Australasia & Oceania', 'Central America & Caribbean', 'Central Asia',
#        'East Asia', 'Eastern Europe', 'Middle East & North Africa',
#        'North America', 'South America', 'South Asia', 'Southeast Asia',
#        'Sub-Saharan Africa', 'Western Europe'],
#       dtype='object', name='region_txt')

# %%
df3.unstack(level=0)['eventid'].plot(kind='line', figsize=(15, 6), grid=True)
plt.legend(title='Regions')
plt.title('Number of attacks per region, per year')

# show the graph
plt.show()
